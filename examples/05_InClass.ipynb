# %% [markdown]
# # Euler's method

# %%
from math import sin
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = (10,8)

def f(x,t):
    return -x**3 + sin(t)

a = 0.0           # Start of the interval
b = 10.0          # End of the interval
N = 1000          # Number of steps
h = (b-a)/N       # Size of a single step
x = 0.0           # Initial condition

tpoints = np.arange(a,b,h)
xpoints = np.zeros(N)
xpoints[0] = x
for i,t in enumerate(tpoints):
    xpoints[i] = xpoints[i-1] + h*f(xpoints[i-1],t)

plt.plot(tpoints,xpoints)
plt.xlabel("t")
plt.ylabel("x(t)")
plt.show()

# %% [markdown]
# # RK2 Method

# %%
from math import sin
import numpy as np
import matplotlib.pyplot as plt

def f(x,t):
    return -x**3 + sin(t)

a = 0.0           # Start of the interval
b = 10.0          # End of the interval
N = 50          # Number of steps
h = (b-a)/N       # Size of a single step
x = 0.0           # Initial condition

tpoints2 = np.arange(a,b,h)
xpoints2 = np.zeros(N)
xpoints2[0] = x
for i,t in enumerate(tpoints2[1:]):
    k1 = h * f(xpoints2[i], t)
    k2 = h * f(xpoints2[i] + 0.5*k1, t + 0.5*h)
    xpoints2[i+1] = xpoints2[i] + k2

plt.plot(tpoints2,xpoints2, label='RK2')
plt.plot(tpoints,xpoints, label='Euler')
plt.xlabel("t")
plt.ylabel("x(t)")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # RK4 method

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(r,t):
    x = r[0]
    y = r[1]
    fx = x*y - x
    fy = y - x*y + np.sin(t)**2
    return np.array([fx,fy],float)

a = 0.0
b = 10.0
N = 1000
h = (b-a)/N

tpoints = np.arange(a,b,h)
r = np.zeros((N,2))
r[0] = [1.0, 1.0]

# To be completed in class: loop over time to solve for x and y, which
# will be stored in r[]
for i,t in enumerate(tpoints[1:],1):
    k1 = h * f(r[i-1], t)
    k2 = h * f(r[i-1] + 0.5*k1, t+0.5*h)
    k3 = h * f(r[i-1] + 0.5*k2, t+0.5*h)
    k4 = h * f(r[i-1]+k3, t+h)
    r[i] = r[i-1] + (k1 + 2*k2 + 2*k3 + k4) / 6


plt.plot(tpoints, r[:,0], label='x')
plt.plot(tpoints, r[:,1], label='y')
plt.xlabel("t")
plt.ylabel("x,y")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(r[:,0], r[:,1])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
def f(r,t):
    x = r[0]
    y = r[1]
    fx = x*y - x
    fy = y - x*y + np.sin(t)**2
    return np.array([fx,fy],float)

a = 0.0
b = 10.0
N = 50
h = (b-a)/N

tpoints0 = np.arange(a,b,h)
r0 = np.zeros((N,2))
r0[0] = [1.0, 1.0]

# To be completed in class: loop over time to solve for x and y, which
# will be stored in r[]
for i,t in enumerate(tpoints0[1:],1):
    k1 = h * f(r0[i-1], t)
    k2 = h * f(r0[i-1] + 0.5*k1, t+0.5*h)
    k3 = h * f(r0[i-1] + 0.5*k2, t+0.5*h)
    k4 = h * f(r0[i-1]+k3, t+h)
    r0[i] = r0[i-1] + (k1 + 2*k2 + 2*k3 + k4) / 6


plt.plot(tpoints0, r0[:,0], label='x')
plt.plot(tpoints0, r0[:,1], label='y')
plt.plot(tpoints, r[:,0], label='x(N=1000)')
plt.plot(tpoints, r[:,1], label='y(N=1000)')
plt.xlabel("t")
plt.ylabel("x,y")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(r[:,0], r[:,1], label="N=1000")
plt.plot(r0[:,0], r0[:,1], label="N=50")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
